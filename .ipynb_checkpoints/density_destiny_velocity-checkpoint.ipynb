# %%
''' Imports '''

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import gizmo_analysis as gizmo
import utilities as ut
import time as t
import gc
from astropy.stats import histogram
import sys

# %%
### LOADING AND READING IN THE SIMULATION (FIRST SNAPSHOT) ###

#simname = '/scratch/04712/tg840119/m12i_m7e3_HD_fire3_fireBH_Sep052021_hr_crdiffc690_sdp1e10_gacc31_fa0.5'                                                         
#simdir = '/scratch/04712/tg840119/m12i_m7e3_HD_fire3_fireBH_Sep052021_hr_crdiffc690_sdp1e10_gacc31_fa0.5'

#part = gizmo.io.Read.read_snapshots(['star','gas'],'index', 200 , simulation_name=simname, simulation_directory=simdir, assign_hosts_rotation=True, assign_hosts=True)

# %%
outpath = '/work2/08006/dbenton/stampede3/velocity/'

# %%
#bins = np.loadtxt('feh_bins.txt')
#counts = np.loadtxt('feh_counts.txt')
#plt.hist(bins[:-1], bins, weights=counts, log=True)
#plt.savefig('hist_out')

# %%
t1 = t.time()

diffuse_outflow_v_z = np.loadtxt(outpath + 'diffuse_outflow_v_z475_501.txt')
diffuse_inflow_v_z = np.loadtxt(outpath + 'diffuse_inflow_v_z475_501.txt')


dense_outflow_v_z = np.loadtxt(outpath + 'dense_outflow_v_z475_501.txt')
dense_inflow_v_z = np.loadtxt(outpath + 'dense_inflow_v_z475_501.txt')
#dense_low_feh475_501.txt
#dense_high_feh475_501.txt

t2 = t.time()
print(t2 - t1)
# Out:
# 0.3312106132507324

# %%
min_inflow_v_z = np.min(np.array(np.min(dense_inflow_v_z),np.min(diffuse_inflow_v_z)))
max_inflow_v_z = np.max(np.array(np.max(dense_inflow_v_z),np.max((diffuse_inflow_v_z))))
min_outflow_v_z = np.min(np.array(np.min(dense_outflow_v_z),np.min(diffuse_outflow_v_z)))
max_outflow_v_z = np.max(np.array(np.max(dense_outflow_v_z),np.max(diffuse_outflow_v_z)))


print(len(diffuse_inflow_v_z))
print(len(dense_inflow_v_z))
print(len(diffuse_outflow_v_z))
print(len(dense_outflow_v_z))


bin_edges_inflow_v_z = np.geomspace(min_inflow_v_z, max_inflow_v_z, 31)
bin_edges_outflow_v_z = np.geomspace(min_outflow_v_z, max_outflow_v_z, 31)


counts_inflow_v_z, bins_inflow_v_z = histogram(dense_inflow_v_z, bins = bin_edges_inflow_v_z)
diff_counts_inflow_v_z, bins_inflow_v_z = histogram(diffuse_inflow_v_z, bins = bin_edges_inflow_v_z)
counts_outflow_v_z, bins_outflow_v_z = histogram(dense_outflow_v_z, bins = bin_edges_outflow_v_z)
diff_counts_outflow_v_z, bins_outflow_v_z = histogram(diffuse_outflow_v_z, bins = bin_edges_outflow_v_z)


frac_counts_inflow_v_z = counts_inflow_v_z/(counts_inflow_v_z+diff_counts_inflow_v_z)
print(frac_counts_inflow_v_z)
frac_counts_outflow_v_z = counts_outflow_v_z/(counts_outflow_v_z+diff_counts_outflow_v_z)
print(frac_counts_outflow_v_z)

binwidth_inflow_v_z = bin_edges_inflow_v_z[1] - bin_edges_inflow_v_z[0]
bin_middles_inflow_v_z = bin_edges_inflow_v_z[0:-1] + binwidth_inflow_v_z/2.
binwidth_outflow_v_z = bin_edges_outflow_v_z[1] - bin_edges_outflow_v_z[0]
bin_middles_outflow_v_z = bin_edges_outflow_v_z[0:-1] + binwidth_outflow_v_z/2.
# Out:
# 208703
# 6493
# 116513
# 3424
# [0.00402955 0.06325707 0.2214342  0.39271255 0.4912     0.558
#  0.63465553 0.66808511 0.67599068 0.70198675 0.74370709 0.75294118
#  0.74612403 0.78362573 0.79358717 0.77916667 0.80400891 0.80238095
#  0.75625    0.74909091 0.7970297  0.74691358 0.7768595  0.83050847
#  0.78125    0.7826087  0.92307692 0.66666667 0.5        1.        ]
# [0.00938208 0.07020997 0.23088456 0.38481013 0.48208469 0.5970696
#  0.59566787 0.66528926 0.69124424 0.69585253 0.73958333 0.69456067
#  0.76833977 0.7195122  0.81132075 0.76691729 0.75294118 0.75770925
#  0.72826087 0.78911565 0.73282443 0.8172043  0.7804878  0.86486486
#  0.82142857 0.77272727 0.75       0.875      1.         1.        ]

# %%
fig, ax = plt.subplots()

ax.plot(bin_middles_outflow_v_z, (frac_counts_outflow_v_z*100.0), label='outflowing gas (z)', color='red', linewidth = 2)
ax.plot(bin_middles_inflow_v_z, (frac_counts_inflow_v_z*100.0), label='inflowing gas (z)', color='blue', linewidth=2)

#snap 200 is 6.432 Gyr
#snap 250 is 8.319 Gyr
#snap 300 is 10.171 Gyr
ax.set_xlabel(r'Instantaneous Density $\ (\frac{n}{cm^{3}})$')
ax.set_ylabel('Percentage of Star Forming Gas Cells')

#ax.set_xlim(5e-5, max_)
#ax.set_ylim(0, 100)
ax.set_xscale('log')


ax.legend(loc='upper left')

# Customize tick labels
#ax.xaxis.set_major_locator(plt.MultipleLocator(base=np.pi / 2))
#ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda val, pos: f'{int(val/np.pi)}π'))

# Customize fonts and font sizes
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 12

# Customize the plot background and frame
#ax.set_facecolor('lightgray')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Add text box
#plt.text(0.65, 0.25, 'm12i FIRE-3 disk\nFe/H ≥ -0.5 (dex)\nz = .5 - present day', transform=ax.transAxes, verticalalignment='top', bbox=dict(facecolor='white'))
#plt.text(0.05, 0.95, 'm12i FIRE-3 disk\nFe/H < -0.5 (dex)\nz = .5 - present day', transform=ax.transAxes,verticalalignment='top', bbox=dict(facecolor='white'))
#top left = 0.05, 0.95
#bottom right = 0.65, 0.25



# Save the plot to a file (optional)
#plt.savefig(outpath + 'D_D_velocity_z_disk',bbox_inches='tight')
plt.tight_layout()
# Display the plot
plt.show()

# %%
delta = frac_counts_inflow_v_z - frac_counts_outflow_v_z

fig, ax = plt.subplots()

ax.plot(bin_middles_inflow_v_z, (delta*100), color='blue', linewidth = 2)
#ax.plot(bin_middles_high_feh, (delta*100), color='red', linewidth = 2)


#snap 200 is 6.432 Gyr
#snap 250 is 8.319 Gyr
#snap 300 is 10.171 Gyr
ax.set_xlabel(r'Instantaneous Density $\ (\frac{n}{cm^{3}})$')
ax.set_ylabel('Delta (% star forming of inflowing (z) - % star forming outflowing (z))')

#ax.set_xlim(5e-5, max_)
#ax.set_ylim(0, 100)
ax.set_xscale('log')


#ax.legend(loc='upper left')

# Customize tick labels
#ax.xaxis.set_major_locator(plt.MultipleLocator(base=np.pi / 2))
#ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda val, pos: f'{int(val/np.pi)}π'))

# Customize fonts and font sizes
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 8

# Customize the plot background and frame
#ax.set_facecolor('lightgray')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Add text box
#plt.text(0.65, 0.25, 'm12i FIRE-3 disk\nFe/H ≥ -0.5 (dex)\nz = .5 - present day', transform=ax.transAxes, verticalalignment='top', bbox=dict(facecolor='white'))
#plt.text(0.05, 0.95, 'm12i FIRE-3 disk\nFe/H < -0.5 (dex)\nz = .5 - present day', transform=ax.transAxes,verticalalignment='top', bbox=dict(facecolor='white'))
#top left = 0.05, 0.95

# Save the plot to a file (optional)
#plt.savefig(outpath + 'delta_D_D_feh_low_feh_bins',bbox_inches='tight')
plt.tight_layout()
# Display the plot
plt.show()

# %%
delta = frac_counts_inflow_v_z - frac_counts_outflow_v_z

fig, ax = plt.subplots()

#ax.plot(bin_middles_inflow_v_z, (delta*100), color='blue', linewidth = 2)
ax.plot(bin_middles_outflow_v_z, (delta*100), color='red', linewidth = 2)


#snap 200 is 6.432 Gyr
#snap 250 is 8.319 Gyr
#snap 300 is 10.171 Gyr
ax.set_xlabel(r'Instantaneous Density $\ (\frac{n}{cm^{3}})$')
ax.set_ylabel('Delta (% star forming of inflowing (z) - % star forming outflowing (z))')

#ax.set_xlim(5e-5, max_)
#ax.set_ylim(0, 100)
ax.set_xscale('log')


#ax.legend(loc='upper left')

# Customize tick labels
#ax.xaxis.set_major_locator(plt.MultipleLocator(base=np.pi / 2))
#ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda val, pos: f'{int(val/np.pi)}π'))

# Customize fonts and font sizes
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 8

# Customize the plot background and frame
#ax.set_facecolor('lightgray')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Add text box
#plt.text(0.65, 0.25, 'm12i FIRE-3 disk\nFe/H ≥ -0.5 (dex)\nz = .5 - present day', transform=ax.transAxes, verticalalignment='top', bbox=dict(facecolor='white'))
#plt.text(0.05, 0.95, 'm12i FIRE-3 disk\nFe/H < -0.5 (dex)\nz = .5 - present day', transform=ax.transAxes,verticalalignment='top', bbox=dict(facecolor='white'))
#top left = 0.05, 0.95

# Save the plot to a file (optional)
plt.savefig(outpath + 'delta_D_D_v_z',bbox_inches='tight')
plt.tight_layout()
# Display the plot
plt.show()

# %%
delta = frac_counts_high_feh - frac_counts_low_feh

fig, ax = plt.subplots()

ax.plot(bin_middles_low_feh, (delta*100), color='blue', linewidth = 2)
ax.plot(bin_middles_high_feh, (delta*100), color='red', linewidth = 2)


#snap 200 is 6.432 Gyr
#snap 250 is 8.319 Gyr
#snap 300 is 10.171 Gyr
ax.set_xlabel(r'Instantaneous Density $\ (\frac{n}{cm^{3}})$')
ax.set_ylabel('Delta (% star forming of High Fe/H - % star forming Low Fe/H)')

#ax.set_xlim(5e-5, max_)
#ax.set_ylim(0, 100)
ax.set_xscale('log')


#ax.legend(loc='upper left')

# Customize tick labels
#ax.xaxis.set_major_locator(plt.MultipleLocator(base=np.pi / 2))
#ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda val, pos: f'{int(val/np.pi)}π'))

# Customize fonts and font sizes
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 8

# Customize the plot background and frame
#ax.set_facecolor('lightgray')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Save the plot to a file (optional)
#plt.savefig(outpath + 'delta_D_D_feh_both_feh_bins',bbox_inches='tight')
plt.tight_layout()
# Display the plot
plt.show()
